# %% [markdown]
# <a href="https://colab.research.google.com/github/PrashantBagri/IP_IIIT_Delhi_2026/blob/main/FMNIST_4_discretize_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train shape: (60000, 28, 28)
# Test shape: (10000, 28, 28)

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0


x_train = x_train.reshape(-1, 28*28)
x_test = x_test.reshape(-1, 28*28)

print(x_train.shape)
# Out:
# (60000, 784)

# %%
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(784,)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.001)


model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train, y_train,
    epochs=60,
    batch_size=128,
    validation_split=0.1
)
# Out:
# Epoch 1/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7775 - loss: 0.6385 - val_accuracy: 0.8355 - val_loss: 0.4603
# Epoch 2/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8546 - loss: 0.4106 - val_accuracy: 0.8597 - val_loss: 0.4069
# Epoch 3/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8682 - loss: 0.3663 - val_accuracy: 0.8712 - val_loss: 0.3658
# Epoch 4/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8777 - loss: 0.3370 - val_accuracy: 0.8728 - val_loss: 0.3538
# Epoch 5/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8836 - loss: 0.3188 - val_accuracy: 0.8762 - val_loss: 0.3400
# Epoch 6/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8894 - loss: 0.3032 - val_accuracy: 0.8832 - val_loss: 0.3451
# Epoch 7/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8950 - loss: 0.2870 - val_accuracy: 0.8805 - val_loss: 0.3367
# Epoch 8/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8961 - loss: 0.2796 - val_accuracy: 0.8820 - val_loss: 0.3322
# Epoch 9/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9014 - loss: 0.2678 - val_accuracy: 0.8813 - val_loss: 0.3329
# Epoch 10/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9050 - loss: 0.2581 - val_accuracy: 0.8773 - val_loss: 0.3230
# Epoch 11/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9075 - loss: 0.2475 - val_accuracy: 0.8848 - val_loss: 0.3293
# Epoch 12/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9100 - loss: 0.2396 - val_accuracy: 0.8862 - val_loss: 0.3350
# Epoch 13/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9115 - loss: 0.2345 - val_accuracy: 0.8860 - val_loss: 0.3307
# Epoch 14/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9151 - loss: 0.2279 - val_accuracy: 0.8892 - val_loss: 0.3268
# Epoch 15/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9174 - loss: 0.2226 - val_accuracy: 0.8893 - val_loss: 0.3258
# Epoch 16/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9193 - loss: 0.2164 - val_accuracy: 0.8875 - val_loss: 0.3176
# Epoch 17/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9234 - loss: 0.2069 - val_accuracy: 0.8872 - val_loss: 0.3354
# Epoch 18/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9247 - loss: 0.2007 - val_accuracy: 0.8890 - val_loss: 0.3301
# Epoch 19/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9255 - loss: 0.1981 - val_accuracy: 0.8867 - val_loss: 0.3427
# Epoch 20/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9290 - loss: 0.1898 - val_accuracy: 0.8885 - val_loss: 0.3349
# Epoch 21/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9296 - loss: 0.1863 - val_accuracy: 0.8892 - val_loss: 0.3377
# Epoch 22/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9319 - loss: 0.1815 - val_accuracy: 0.8870 - val_loss: 0.3627
# Epoch 23/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9327 - loss: 0.1769 - val_accuracy: 0.8833 - val_loss: 0.3673
# Epoch 24/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9343 - loss: 0.1754 - val_accuracy: 0.8887 - val_loss: 0.4014
# Epoch 25/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9364 - loss: 0.1690 - val_accuracy: 0.8867 - val_loss: 0.3707
# Epoch 26/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9378 - loss: 0.1652 - val_accuracy: 0.8907 - val_loss: 0.3539
# Epoch 27/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9404 - loss: 0.1577 - val_accuracy: 0.8877 - val_loss: 0.3667
# Epoch 28/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9416 - loss: 0.1568 - val_accuracy: 0.8902 - val_loss: 0.3771
# Epoch 29/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9418 - loss: 0.1556 - val_accuracy: 0.8855 - val_loss: 0.3684
# Epoch 30/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9430 - loss: 0.1509 - val_accuracy: 0.8862 - val_loss: 0.3838
# Epoch 31/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9445 - loss: 0.1463 - val_accuracy: 0.8882 - val_loss: 0.3996
# Epoch 32/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9459 - loss: 0.1437 - val_accuracy: 0.8858 - val_loss: 0.4057
# Epoch 33/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9479 - loss: 0.1384 - val_accuracy: 0.8902 - val_loss: 0.3799
# Epoch 34/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9498 - loss: 0.1347 - val_accuracy: 0.8847 - val_loss: 0.4226
# Epoch 35/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9505 - loss: 0.1311 - val_accuracy: 0.8902 - val_loss: 0.4152
# Epoch 36/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9502 - loss: 0.1306 - val_accuracy: 0.8830 - val_loss: 0.4395
# Epoch 37/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9509 - loss: 0.1285 - val_accuracy: 0.8878 - val_loss: 0.4253
# Epoch 38/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9517 - loss: 0.1261 - val_accuracy: 0.8842 - val_loss: 0.4456
# Epoch 39/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9538 - loss: 0.1224 - val_accuracy: 0.8843 - val_loss: 0.4782
# Epoch 40/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9533 - loss: 0.1234 - val_accuracy: 0.8818 - val_loss: 0.4487
# Epoch 41/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9555 - loss: 0.1160 - val_accuracy: 0.8857 - val_loss: 0.4795
# Epoch 42/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9574 - loss: 0.1113 - val_accuracy: 0.8842 - val_loss: 0.4653
# Epoch 43/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9546 - loss: 0.1186 - val_accuracy: 0.8883 - val_loss: 0.4528
# Epoch 44/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9575 - loss: 0.1111 - val_accuracy: 0.8888 - val_loss: 0.4559
# Epoch 45/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9589 - loss: 0.1069 - val_accuracy: 0.8867 - val_loss: 0.4595
# Epoch 46/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9581 - loss: 0.1098 - val_accuracy: 0.8885 - val_loss: 0.4614
# Epoch 47/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9584 - loss: 0.1091 - val_accuracy: 0.8858 - val_loss: 0.4584
# Epoch 48/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9614 - loss: 0.1023 - val_accuracy: 0.8853 - val_loss: 0.4809
# Epoch 49/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9627 - loss: 0.0972 - val_accuracy: 0.8870 - val_loss: 0.5023
# Epoch 50/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9625 - loss: 0.0978 - val_accuracy: 0.8858 - val_loss: 0.5196
# Epoch 51/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9617 - loss: 0.1015 - val_accuracy: 0.8830 - val_loss: 0.4831
# Epoch 52/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9643 - loss: 0.0939 - val_accuracy: 0.8893 - val_loss: 0.5067
# Epoch 53/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9641 - loss: 0.0954 - val_accuracy: 0.8910 - val_loss: 0.4764
# Epoch 54/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9649 - loss: 0.0927 - val_accuracy: 0.8842 - val_loss: 0.4944
# Epoch 55/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9672 - loss: 0.0868 - val_accuracy: 0.8857 - val_loss: 0.5318
# Epoch 56/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9673 - loss: 0.0884 - val_accuracy: 0.8892 - val_loss: 0.5389
# Epoch 57/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9684 - loss: 0.0842 - val_accuracy: 0.8865 - val_loss: 0.5432
# Epoch 58/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9676 - loss: 0.0864 - val_accuracy: 0.8882 - val_loss: 0.5233
# Epoch 59/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9674 - loss: 0.0870 - val_accuracy: 0.8895 - val_loss: 0.5193
# Epoch 60/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9688 - loss: 0.0826 - val_accuracy: 0.8913 - val_loss: 0.5242

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8897 - loss: 0.5556
# Test accuracy: 0.8896999955177307

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 334,544 (1.28 MB)
#  Trainable params: 111,514 (435.60 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 223,030 (871.21 KB)

# %%
import matplotlib.pyplot as plt

dense_layers = []

for layer in model.layers:

    if isinstance(layer, keras.layers.Dense):
        dense_layers.append(layer)


# w0 = dense_layers[0].get_weights()[0]
# w1 = dense_layers[1].get_weights()[0]
# w2 = dense_layers[2].get_weights()[0]
w3 = dense_layers[3].get_weights()[0]

# b0 = dense_layers[0].get_weights()[1]
# b1 = dense_layers[1].get_weights()[1]
# b2 = dense_layers[2].get_weights()[1]
b3 = dense_layers[3].get_weights()[1]

# %%
# w0_plot = dense_layers[0].get_weights()[0].reshape(-1)
# plt.figure(figsize=(6, 4))
# plt.hist(w0_plot, bins=200)
# plt.xlabel("Float weight value")
# plt.ylabel("Count")
# plt.title("Float model weight histogram (Input → Hidden)")
# # plt.xlim([-4, 4])
# plt.show()

# w1_plot = dense_layers[1].get_weights()[0].reshape(-1)

# plt.figure(figsize=(6, 4))
# plt.hist(w1_plot, bins=200)
# plt.xlabel("Float weight value")
# plt.ylabel("Count")
# plt.title("Float model weight histogram (Hidden → Output)")
# # plt.xlim([-4, 4])
# plt.show()

# w2_plot = dense_layers[2].get_weights()[0].reshape(-1)

# plt.figure(figsize=(6, 4))
# plt.hist(w2_plot, bins=200)
# plt.xlabel("Float weight value")
# plt.ylabel("Count")
# plt.title("Float model weight histogram (Hidden → Output)")
# # plt.xlim([-4, 4])
# plt.show()

w3_plot = dense_layers[3].get_weights()[0].reshape(-1)

plt.figure(figsize=(6, 4))
plt.hist(w3_plot, bins=200)
plt.xlabel("Float weight value")
plt.ylabel("Count")
plt.title("Float model weight histogram (Hidden → Output)")
# plt.xlim([-4, 4])
plt.show()

# %%
# print(f"\n\n{w0}\n\n{w1}\n\n{w2}\n\n{w3}\n\n")

# w2.ndim
# w1
# w2
# w3

# %%
# levels1 = [-1.0 , -0.75, -0.25, 0.0 , 0.25, 0.75, 1.0]
levels = [-1.0 , -0.75, -0.25, 0.0 , 0.25, 0.75, 1.0]


def snap_weights_to_levels(weights, levels):


    levels = np.array(levels)
    snapped = np.zeros_like(weights)

    for i in range(weights.shape[0]):
        for j in range(weights.shape[1]):
            w = weights[i, j]


            if w <= levels[0]:
                snapped[i, j] = levels[0]
                continue
            if w >= levels[-1]:
                snapped[i, j] = levels[-1]
                continue


            for k in range(len(levels) - 1):
                low = levels[k]
                high = levels[k + 1]

                if low <= w <= high:
                    midpoint = (low + high) / 2

                    if w > midpoint:
                        snapped[i, j] = high
                    else:
                        snapped[i, j] = low
                    break

    return snapped

# %%
# snapped_w0 = snap_weights_to_levels(w0, levels)
# snapped_w1 = snap_weights_to_levels(w1, levels)
# snapped_w2 = snap_weights_to_levels(w2, levels)
snapped_w3 = snap_weights_to_levels(w3, levels)


# snapped_w0
# snapped_w1
# snapped_w2
# snapped_w3

# %%
# dense_layers[0].set_weights([snapped_w0, b0])
# dense_layers[1].set_weights([snapped_w1, b1])
# dense_layers[2].set_weights([snapped_w2, b2])
dense_layers[3].set_weights([snapped_w3, b3])

# %%
# w0_plot = dense_layers[0].get_weights()[0].reshape(-1)
# plt.figure(figsize=(6, 4))
# plt.hist(w0_plot, bins=200)
# plt.xlabel("Float weight value")
# plt.ylabel("Count")
# plt.title("Float model weight histogram (Input → Hidden)")
# # plt.xlim([-4, 4])
# plt.show()

# w1_plot = dense_layers[1].get_weights()[0].reshape(-1)

# plt.figure(figsize=(6, 4))
# plt.hist(w1_plot, bins=200)
# plt.xlabel("Float weight value")
# plt.ylabel("Count")
# plt.title("Float model weight histogram (Hidden → Output)")
# # plt.xlim([-4, 4])
# plt.show()

# w2_plot = dense_layers[2].get_weights()[0].reshape(-1)

# plt.figure(figsize=(6, 4))
# plt.hist(w2_plot, bins=200)
# plt.xlabel("Float weight value")
# plt.ylabel("Count")
# plt.title("Float model weight histogram (Hidden → Output)")
# # plt.xlim([-4, 4])
# plt.show()

w3_plot = dense_layers[3].get_weights()[0].reshape(-1)

plt.figure(figsize=(6, 4))
plt.hist(w3_plot, bins=200)
plt.xlabel("Float weight value")
plt.ylabel("Count")
plt.title("Float model weight histogram (Hidden → Output)")
# plt.xlim([-4, 4])
plt.show()

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8687 - loss: 0.6177
# Test accuracy: 0.8687000274658203

# %%
history = model.fit(
    x_train, y_train,
    epochs=60,
    batch_size=128,
    validation_split=0.1
)
# Out:
# Epoch 1/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9676 - loss: 0.0878 - val_accuracy: 0.8855 - val_loss: 0.5137
# Epoch 2/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9701 - loss: 0.0794 - val_accuracy: 0.8888 - val_loss: 0.5129
# Epoch 3/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9711 - loss: 0.0764 - val_accuracy: 0.8807 - val_loss: 0.5730
# Epoch 4/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9708 - loss: 0.0764 - val_accuracy: 0.8863 - val_loss: 0.5768
# Epoch 5/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9712 - loss: 0.0771 - val_accuracy: 0.8833 - val_loss: 0.6762
# Epoch 6/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9700 - loss: 0.0785 - val_accuracy: 0.8920 - val_loss: 0.5311
# Epoch 7/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9714 - loss: 0.0740 - val_accuracy: 0.8895 - val_loss: 0.5268
# Epoch 8/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9723 - loss: 0.0736 - val_accuracy: 0.8858 - val_loss: 0.6148
# Epoch 9/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9739 - loss: 0.0681 - val_accuracy: 0.8878 - val_loss: 0.5556
# Epoch 10/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9744 - loss: 0.0681 - val_accuracy: 0.8853 - val_loss: 0.5724
# Epoch 11/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9740 - loss: 0.0683 - val_accuracy: 0.8890 - val_loss: 0.5935
# Epoch 12/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9736 - loss: 0.0689 - val_accuracy: 0.8862 - val_loss: 0.6008
# Epoch 13/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9732 - loss: 0.0698 - val_accuracy: 0.8850 - val_loss: 0.6340
# Epoch 14/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9757 - loss: 0.0640 - val_accuracy: 0.8845 - val_loss: 0.5965
# Epoch 15/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9765 - loss: 0.0633 - val_accuracy: 0.8893 - val_loss: 0.6464
# Epoch 16/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9776 - loss: 0.0610 - val_accuracy: 0.8888 - val_loss: 0.6486
# Epoch 17/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9763 - loss: 0.0651 - val_accuracy: 0.8833 - val_loss: 0.6502
# Epoch 18/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9754 - loss: 0.0656 - val_accuracy: 0.8850 - val_loss: 0.6305
# Epoch 19/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9771 - loss: 0.0612 - val_accuracy: 0.8877 - val_loss: 0.6391
# Epoch 20/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9769 - loss: 0.0615 - val_accuracy: 0.8892 - val_loss: 0.6042
# Epoch 21/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9751 - loss: 0.0651 - val_accuracy: 0.8860 - val_loss: 0.6042
# Epoch 22/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9795 - loss: 0.0546 - val_accuracy: 0.8898 - val_loss: 0.6267
# Epoch 23/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9790 - loss: 0.0537 - val_accuracy: 0.8823 - val_loss: 0.7575
# Epoch 24/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9769 - loss: 0.0642 - val_accuracy: 0.8878 - val_loss: 0.6712
# Epoch 25/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9783 - loss: 0.0588 - val_accuracy: 0.8843 - val_loss: 0.6408
# Epoch 26/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9791 - loss: 0.0556 - val_accuracy: 0.8880 - val_loss: 0.6674
# Epoch 27/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9801 - loss: 0.0534 - val_accuracy: 0.8882 - val_loss: 0.6920
# Epoch 28/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9801 - loss: 0.0525 - val_accuracy: 0.8825 - val_loss: 0.7248
# Epoch 29/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9792 - loss: 0.0550 - val_accuracy: 0.8902 - val_loss: 0.6479
# Epoch 30/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9787 - loss: 0.0570 - val_accuracy: 0.8807 - val_loss: 0.7898
# Epoch 31/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9802 - loss: 0.0527 - val_accuracy: 0.8858 - val_loss: 0.7032
# Epoch 32/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9817 - loss: 0.0488 - val_accuracy: 0.8870 - val_loss: 0.6714
# Epoch 33/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9797 - loss: 0.0571 - val_accuracy: 0.8845 - val_loss: 0.6670
# Epoch 34/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9814 - loss: 0.0512 - val_accuracy: 0.8868 - val_loss: 0.6741
# Epoch 35/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9818 - loss: 0.0482 - val_accuracy: 0.8827 - val_loss: 0.7099
# Epoch 36/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9818 - loss: 0.0481 - val_accuracy: 0.8893 - val_loss: 0.7001
# Epoch 37/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9805 - loss: 0.0532 - val_accuracy: 0.8887 - val_loss: 0.7045
# Epoch 38/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9809 - loss: 0.0516 - val_accuracy: 0.8857 - val_loss: 0.7159
# Epoch 39/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9834 - loss: 0.0442 - val_accuracy: 0.8855 - val_loss: 0.7357
# Epoch 40/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9835 - loss: 0.0441 - val_accuracy: 0.8797 - val_loss: 0.7716
# Epoch 41/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9818 - loss: 0.0504 - val_accuracy: 0.8812 - val_loss: 0.7294
# Epoch 42/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9836 - loss: 0.0451 - val_accuracy: 0.8793 - val_loss: 0.8641
# Epoch 43/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9805 - loss: 0.0534 - val_accuracy: 0.8863 - val_loss: 0.7126
# Epoch 44/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9831 - loss: 0.0464 - val_accuracy: 0.8837 - val_loss: 0.7440
# Epoch 45/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9861 - loss: 0.0390 - val_accuracy: 0.8890 - val_loss: 0.7927
# Epoch 46/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9856 - loss: 0.0395 - val_accuracy: 0.8900 - val_loss: 0.7530
# Epoch 47/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9843 - loss: 0.0411 - val_accuracy: 0.8917 - val_loss: 0.7437
# Epoch 48/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9795 - loss: 0.0563 - val_accuracy: 0.8890 - val_loss: 0.7692
# Epoch 49/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9832 - loss: 0.0463 - val_accuracy: 0.8860 - val_loss: 0.7984
# Epoch 50/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9828 - loss: 0.0473 - val_accuracy: 0.8807 - val_loss: 0.8203
# Epoch 51/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9859 - loss: 0.0378 - val_accuracy: 0.8857 - val_loss: 0.8163
# Epoch 52/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9851 - loss: 0.0395 - val_accuracy: 0.8815 - val_loss: 0.8265
# Epoch 53/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9851 - loss: 0.0409 - val_accuracy: 0.8838 - val_loss: 0.7936
# Epoch 54/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9862 - loss: 0.0375 - val_accuracy: 0.8880 - val_loss: 0.8291
# Epoch 55/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9851 - loss: 0.0404 - val_accuracy: 0.8863 - val_loss: 0.7710
# Epoch 56/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9845 - loss: 0.0420 - val_accuracy: 0.8887 - val_loss: 0.7526
# Epoch 57/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9839 - loss: 0.0446 - val_accuracy: 0.8812 - val_loss: 0.7734
# Epoch 58/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9864 - loss: 0.0380 - val_accuracy: 0.8833 - val_loss: 0.7908
# Epoch 59/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9857 - loss: 0.0396 - val_accuracy: 0.8897 - val_loss: 0.8439
# Epoch 60/60
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9862 - loss: 0.0384 - val_accuracy: 0.8805 - val_loss: 0.8271

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8783 - loss: 0.8784
# Test accuracy: 0.8783000111579895

# %%
# w2 = dense_layers[0].get_weights()[0].reshape(-1)
# plt.figure(figsize=(6, 4))
# plt.hist(w2, bins=200)
# plt.xlabel("Float weight value")
# plt.ylabel("Count")
# plt.title("Float model weight histogram (Input → Hidden)")
# plt.xlim([-1, 1])
# plt.show()

# w2 = dense_layers[1].get_weights()[0].reshape(-1)

# plt.figure(figsize=(6, 4))
# plt.hist(w2, bins=200)
# plt.xlabel("Float weight value")
# plt.ylabel("Count")
# plt.title("Float model weight histogram (Hidden → Output)")
# plt.xlim([-1, 1])
# plt.show()

# w2 = dense_layers[2].get_weights()[0].reshape(-1)

# plt.figure(figsize=(6, 4))
# plt.hist(w2, bins=200)
# plt.xlabel("Float weight value")
# plt.ylabel("Count")
# plt.title("Float model weight histogram (Hidden → Output)")
# plt.xlim([-1, 1])
# plt.show()
w2 = dense_layers[3].get_weights()[0].reshape(-1)

plt.figure(figsize=(6, 4))
plt.hist(w2, bins=200)
plt.xlabel("Float weight value")
plt.ylabel("Count")
plt.title("Float model weight histogram (Hidden → Output)")
plt.xlim([-1,1])
plt.show()
